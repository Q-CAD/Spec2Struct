# %%
import json
import numpy as np

import ase
import ase.io
from ase import Atoms

# %%
train_path = "data/mp_dos/train.json"
test_path = "data/mp_dos/test.json"
valid_path = "data/mp_dos/val.json"

# %%
f = open(train_path, "r")
train_data = json.load(f)
f.close()

f = open(test_path, "r")
test_data = json.load(f)
f.close()

f = open(valid_path, "r")
valid_data = json.load(f)
f.close()

# %%
def create_super_dataset(data):
    pass

# %%
l = []
for each in train_data:
    n = len(each['atomic_numbers'])
    l.append(n)

# %%
max(l)
# Out:
# 82

# %%
np.mean(l)
# Out:
# np.float64(13.437454879569469)

# %%
count = 0

for each in l:
    if 40 <= each <= 50:
        count += 1

# %%
count
# Out:
# 778

# %%
new_data = []

for each in train_data:
    n = len(each['atomic_numbers'])
    if 40 <= n <= 50:
        new_data.append(each)

# %%
print(len(new_data))
# Out:
# 778

# %%
with open("data/mp_dos_4050/train.json", "w") as f:
    json.dump(new_data, f)
